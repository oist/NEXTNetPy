# %%
import nmepinet as nmen
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %%
SIZE=10**4
SIM=20000
SEED=1
pk,knn = nmen.depleted_distribution(SIZE,SIM,SEED)
zk=nmen.simulation_discrete_zk(SIZE,SIM,SEED)
# Out:
# 19999 / 20000

# %%
np.save('pk.npy', pk) # save
np.save('knn.npy', knn) # save

# %%
k=np.arange(0,len(pk[0]))
plt.scatter(k,pk[0])
plt.scatter([k for k in range(1,10**2)],[4/(k*(k+1)*(k+2)) for k in range(1,10**2)])
# plt.scatter(k,pk[1])
plt.yscale("log")
plt.xscale("log")
plt.show()

# %%
len(pk)
# Out:
# 27

# %%
step = 12
plt.scatter(k,np.array(zk[step])*pk[step][1]/zk[step][1])
plt.scatter(k,pk[step])
plt.yscale("log")
plt.xscale("log")

# %%
step = 10
k1 = np.array([sum([ki**1 * pk[step][ki] for ki in range(0,len(pk[0]))]) for step in range(0,len(pk))])
fn=[(pk[step][ki] / k1[step])/(zk[step][ki]) if (zk[step][ki])!= 0 else 0 for ki in range(0,len(pk[0]))]
fn=[( (zk[step][ki])/pk[0][ki]) if (pk[0][ki])!= 0 else 0 for ki in range(0,len(pk[0]))]

plt.scatter(k,fn)
plt.yscale("log")
plt.xscale("log")
plt.yl

# %%
plt.scatter(k,fn)
plt.yscale("log")
plt.xscale("log")

# %%
k=np.arange(0,len(knn[0]))
plt.scatter(k,knn[0])
# plt.scatter([k for k in range(1,10**2)],[4/(k*(k+1)*(k+2)) for k in range(1,10**2)])
plt.scatter(k,knn[9])
plt.yscale("log")
plt.xscale("log")
plt.show()

# %%
n=np.arange(0,len(moments))
m=np.array(moments)
plt.scatter(n,[sum([ki**1 *pk[step][ki] for ki in range(0,len(pk[0]))]) for step in range(0,len(n))])
epsilon = 0.12
plt.plot(n,(1-epsilon)**n *k1)
# plt.ylim([0,3])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Define the logistic function
def logistic_function(x, k, x0):
    return 25.32 / (1 + np.exp(-k * (x - x0)))

# Generate some example data
n=np.arange(0,len(moments))
x_data = n[0:-1]
y_data = [sum([ki**2 * pk[step][ki] for ki in range(1,len(pk[0]))]) for step in range(0,len(n)-1)]

# Fit the logistic function to the data
popt, pcov = curve_fit(logistic_function, x_data, y_data)

# Extract the optimized parameters
k_opt, x0_opt = popt

# Generate the fitted curve
y_fit = logistic_function(x_data, k_opt, x0_opt)

# Plot the original data and the fitted curve
plt.scatter(x_data, y_data, label='Data')
plt.plot(x_data, y_fit, label='Fitted curve', color='red')
# plt.plot(x_data, logistic_function(x_data,-0.5,10), label='Fitted curve', color='red')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Logistic Function Fitting')
plt.show()

# %%
y_data
# Out:
# [25.321460000000005,
#  25.321425991262835,
#  25.263606202622707,
#  24.966992055239796,
#  24.166750017343514,
#  22.716043238423605,
#  20.602989059568035,
#  18.017451472494106,
#  15.281388167220996,
#  12.702871506118052,
#  10.405992116335929,
#  8.495942696439535,
#  6.96024307133233,
#  5.727618007358586,
#  4.7303406893544775,
#  3.9268836820559363,
#  3.2735627075882707,
#  nan]

# %%
np.round(m[:,0])
# Out:
# array([ 2.0000e+00, -2.0000e+00, -9.0000e+00, -2.1000e+01, -3.6000e+01,
#        -7.2000e+01, -1.9000e+02, -5.6900e+02, -1.5360e+03, -3.3030e+03,
#        -5.4990e+03, -7.8820e+03, -1.0689e+04, -1.3632e+04, -1.6134e+04,
#        -1.7937e+04])

# %%
nmen.simulate_discrete()
